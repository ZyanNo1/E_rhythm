# %%
import pymysql

data = [
    ("植物意象", "蒹葭（芦苇）", "初生芦苇与荻的合称", "求而不得的怅惘、理想与现实的阻隔", "蒹葭苍苍，白露为霜。所谓伊人，在水一方——《诗经·秦风·蒹葭》"),
    ("植物意象", "红豆（相思子）", "红色心形种子", "爱情与思念", "玲珑骰子安红豆，入骨相思知不知——温庭筠《新添声杨柳枝词》"),
    ("植物意象", "青松", "常绿乔木", "坚贞不屈的品格", "大雪压青松，青松挺且直——陈毅《青松》"),
    ("植物意象", "梅花", "冬季开花植物", "孤傲高洁、逆境中的坚韧", "疏影横斜水清浅，暗香浮动月黄昏——林逋《山园小梅》"),
    ("植物意象", "梧桐", "落叶乔木", "离愁别绪、孤独凄凉", "寂寞梧桐深院锁清秋——李煜《相见欢》"),
    ("植物意象", "菊花", "秋季花卉", "隐逸淡泊、超脱世俗", "不是花中偏爱菊，此花开尽更无花——元稹《菊花》"),
    ("植物意象", "莲荷", "水生花卉", "出淤泥而不染的高洁", "接天莲叶无穷碧，映日荷花别样红——杨万里《晓出净慈寺送林子方》"),
    ("植物意象", "杨柳", "垂柳枝条", "离别与挽留", "渭城朝雨浥轻尘，客舍青青柳色新——王维《送元二使安西》"),
    ("植物意象", "斑竹（湘妃竹）", "带斑点的竹子", "忠贞爱情或哀思", "斑竹枝，斑竹枝，泪痕点点寄相思——刘禹锡《潇湘神》"),
    ("植物意象", "黍离", "谷物作物", "亡国之痛、世事变迁", "彼黍离离，彼稷之苗——《诗经·黍离》"),
    ("植物意象", "幽兰", "深山兰花", "君子品格、孤芳自赏", "幽兰生前庭，含薰待清风——陶渊明《饮酒》"),
    ("植物意象", "棠梨", "野生梨树", "乡愁与时光流逝", "棠梨叶落胭脂色，荞麦花开白雪香——王禹偁《村行》"),
    ("植物意象", "茱萸", "芳香草本植物", "重阳思亲、辟邪祈福", "遥知兄弟登高处，遍插茱萸少一人——王维《九月九日忆山东兄弟》"),
    ("植物意象", "浮萍", "水生漂浮植物", "漂泊无依、人生无常", "浮萍寄清水，随风东西流——曹植《浮萍篇》"),
    ("植物意象", "荆棘", "带刺灌木", "人生困境、仕途艰险", "荆棘满途，壮志难酬——杜甫《梦李白》"),
    ("植物意象", "苔痕", "青苔痕迹", "幽静隐逸、岁月沉淀", "苔痕上阶绿，草色入帘青——刘禹锡《陋室铭》"),
    ("植物意象", "蒲草", "湿地草本植物", "坚韧柔韧、民间疾苦", "蒲草韧如丝，磐石无转移——《孔雀东南飞》"),
    ("植物意象", "落花", "凋谢的花朵", "青春易逝、美好事物消逝", "流水落花春去也，天上人间——李煜《浪淘沙》"),
    ("植物意象", "芭蕉", "阔叶植物", "孤独愁绪、雨夜寂寥", "窗前谁种芭蕉树？阴满中庭——李清照《添字丑奴儿》"),
    ("植物意象", "芳草", "香草或春草", "离愁别恨、春意盎然", "晴川历历汉阳树，芳草萋萋鹦鹉洲——崔颢《黄鹤楼》"),
]

conn = pymysql.connect(
    host='localhost',
    user='root',
    password='lzy18762501',
    database='e_rhythm',
    charset='utf8mb4'
)
cur = conn.cursor()
sql = "INSERT INTO yixiang (category, name, body, meaning, example) VALUES (%s, %s, %s, %s, %s)"
cur.executemany(sql, data)
conn.commit()
cur.close()
conn.close()
print("导入完成")
# Out:
# 导入完成

# %%
import pymysql

data = [
    ("动物意象", "鸿雁", "迁徙候鸟", "思乡怀亲、羁旅漂泊", "雁字回时，月满西楼——李清照《一剪梅》"),
    ("动物意象", "青鸟", "神话中的信使鸟", "爱情或佳音传递", "蓬山此去无多路，青鸟殷勤为探看——李商隐《无题》"),
    ("动物意象", "寒蝉", "秋日鸣蝉", "悲凉凄切、生命短暂", "寒蝉凄切，对长亭晚——柳永《雨霖铃》"),
    ("动物意象", "燕子", "候鸟，春归秋去", "春光易逝、离愁别绪", "无可奈何花落去，似曾相识燕归来——晏殊《浣溪沙》"),
    ("动物意象", "鸥鸟", "水边自由鸟类", "隐逸闲适、超脱世俗", "飘飘何所似，天地一沙鸥——杜甫《旅夜书怀》"),
    ("动物意象", "黄鹂", "春日鸣禽", "生机盎然、欢快明媚", "两个黄鹂鸣翠柳，一行白鹭上青天——杜甫《绝句》"),
    ("动物意象", "乌鸦", "黑色鸟类", "衰败不祥、孤寂荒凉", "枯藤老树昏鸦——马致远《天净沙·秋思》"),
    ("动物意象", "杜鹃", "啼血之鸟", "亡国之痛、哀伤凄厉", "庄生晓梦迷蝴蝶，望帝春心托杜鹃——李商隐《锦瑟》"),
    ("动物意象", "白鹭", "白色水鸟", "高洁自由、灵动之美", "一行白鹭上青天——杜甫《绝句》"),
    ("动物意象", "鸳鸯", "双栖水禽", "夫妻恩爱、忠贞不渝", "得成比目何辞死，愿作鸳鸯不羡仙——卢照邻《长安古意》"),
    ("动物意象", "猿猴", "深山长啸之兽", "孤寂哀愁、羁旅之悲", "风急天高猿啸哀——杜甫《登高》"),
    ("动物意象", "马", "骏马或战马", "壮志豪情、征战沙场", "何当金络脑，快走踏清秋——李贺《马诗》"),
    ("动物意象", "鹤", "仙禽", "长寿高洁、超凡脱俗", "晴空一鹤排云上，便引诗情到碧霄——刘禹锡《秋词》"),
    ("动物意象", "蟋蟀", "秋虫", "时光流逝、思妇怀远", "七月在野，八月在宇，九月在户——《诗经·七月》"),
    ("动物意象", "蝴蝶", "春日飞虫", "自由闲适、虚幻梦境", "庄生晓梦迷蝴蝶——李商隐《锦瑟》"),
    ("动物意象", "牛", "耕畜", "勤劳奉献、民生疾苦", "耕犁千亩实千箱，力尽筋疲谁复伤——李纲《病牛》"),
    ("动物意象", "蚕", "吐丝昆虫", "自我牺牲、奉献精神", "春蚕到死丝方尽——李商隐《无题》"),
    ("动物意象", "鹰鹫", "猛禽", "勇猛刚烈、孤高傲世", "鹰击长空，鱼翔浅底——毛泽东《沁园春·长沙》"),
    ("动物意象", "鲤鱼", "吉祥鱼类", "仕途顺遂、书信传递", "客从远方来，遗我双鲤鱼——汉乐府《饮马长城窟行》"),
    ("动物意象", "蜗牛", "缓慢爬行之虫", "卑微坚韧、人生困顿", "蜗牛角上争何事——白居易《对酒》"),
]

conn = pymysql.connect(
    host='localhost',
    user='root',
    password='lzy18762501',
    database='e_rhythm',
    charset='utf8mb4'
)
cur = conn.cursor()
sql = "INSERT INTO yixiang (category, name, body, meaning, example) VALUES (%s, %s, %s, %s, %s)"
cur.executemany(sql, data)
conn.commit()
cur.close()
conn.close()
print("导入完成")
# Out:
# 导入完成

# %%
import pymysql

data = [
    ("自然意象", "青山", "苍翠山峦", "永恒、隐逸、乡愁", "青山依旧在，几度夕阳红——杨慎《临江仙》"),
    ("自然意象", "明月", "夜空明月", "思乡、孤高、永恒", "海上生明月，天涯共此时——张九龄《望月怀远》"),
    ("自然意象", "白云", "空中云气", "自由、漂泊、仙逸", "行到水穷处，坐看云起时——王维《终南别业》"),
    ("自然意象", "落日", "西沉太阳", "迟暮、壮美、终结", "大漠孤烟直，长河落日圆——王维《使至塞上》"),
    ("自然意象", "秋风", "秋季凉风", "萧瑟、离愁、肃杀", "秋风起兮白云飞——刘彻《秋风辞》"),
    ("自然意象", "春雨", "春季细雨", "生机、缠绵、润物", "小楼一夜听春雨——陆游《临安春雨初霁》"),
    ("自然意象", "冰雪", "冬令气象", "高洁、严酷、纯净", "瀚海阑干百丈冰——岑参《白雪歌》"),
    ("自然意象", "江水", "奔流河水", "时间、愁绪、永恒", "唯见长江天际流——李白《黄鹤楼送孟浩然》"),
    ("自然意象", "沧海", "浩瀚海洋", "壮志、变迁、永恒", "曾经沧海难为水——元稹《离思》"),
    ("自然意象", "孤舟", "独行小船", "漂泊、孤寂、超脱", "孤舟蓑笠翁——柳宗元《江雪》"),
    ("自然意象", "疏桐", "稀疏梧桐", "孤高、清冷、秋意", "缺月挂疏桐，漏断人初静——苏轼《卜算子》"),
    ("自然意象", "寒鸦", "秋冬乌鸦", "荒凉、哀思、暮气", "枯藤老树昏鸦——马致远《天净沙·秋思》"),
    ("自然意象", "残荷", "凋败荷叶", "坚韧、衰败、余韵", "留得残荷听雨声——李商隐《宿骆氏亭》"),
    ("自然意象", "空谷", "幽深山谷", "寂寥、禅意、回响", "空山不见人，但闻人语响——王维《鹿柴》"),
    ("自然意象", "石泉", "山间清泉", "纯净、永恒、天籁", "明月松间照，清泉石上流——王维《山居秋暝》"),
    ("自然意象", "蓼花", "水边野花", "野趣、漂泊、愁绪", "蓼花被堤岸，陂水寒更绿——柳宗元《田家》"),
    ("自然意象", "沙雁", "大雁", "迁徙、信使、思乡", "雁字回时，月满西楼——李清照《一剪梅》"),
    ("自然意象", "冻云", "冬云", "压抑、凛冽、肃杀", "冻云黯淡天气——柳永《夜半乐》"),
    ("自然意象", "烟柳", "雾中柳树", "朦胧、柔情、春愁", "烟柳画桥，风帘翠幕——柳永《望海潮》"),
    ("自然意象", "苔痕", "青苔痕迹", "幽寂、岁月、隐逸", "苔痕上阶绿，草色入帘青——刘禹锡《陋室铭》"),
]

conn = pymysql.connect(
    host='localhost',
    user='root',
    password='lzy18762501',
    database='e_rhythm',
    charset='utf8mb4'
)
cur = conn.cursor()
sql = "INSERT INTO yixiang (category, name, body, meaning, example) VALUES (%s, %s, %s, %s, %s)"
cur.executemany(sql, data)
conn.commit()
cur.close()
conn.close()
print("导入完成")
# Out:
# 导入完成

# %%
import pymysql

data = [
    ("地理意象", "阳关", "甘肃敦煌西陲关隘", "文明疆界、空间断裂、送别仪式", "劝君更尽一杯酒，西出阳关无故人——王维《送元二使安西》"),
    ("地理意象", "潇湘", "湖南水域综合体", "愁绪、贬谪、乡愁", "雁尽书难寄，愁多梦不成——沈如筠《闺怨》"),
    ("地理意象", "巫山", "重庆长江三峡段", "情爱、欲望升华、审美范式", "曾经沧海难为水，除却巫山不是云——元稹《离思》"),
    ("地理意象", "陇头", "甘肃陇山要冲", "边塞苦寒、流水呜咽、丝路回响", "陇头流水，流离山下——北朝民歌《陇头歌辞》"),
    ("地理意象", "洞庭", "长江中游湖泊", "宦海沉浮、政治压迫、宿命观", "吴楚东南坼，乾坤日夜浮——杜甫《登岳阳楼》"),
    ("地理意象", "碣石", "渤海沿岸山崖", "帝王雄心、时空永恒", "东临碣石，以观沧海——曹操《观沧海》"),
    ("地理意象", "轮台", "新疆戍所", "苦寒、报国、边塞符号", "轮台九月风夜吼——岑参《走马川行》"),
    ("地理意象", "白帝城", "重庆瞿塘峡口", "政治流放、江峡险绝", "朝辞白帝彩云间——李白《早发白帝城》"),
    ("地理意象", "鹳雀楼", "山西永济黄河东岸", "登高望远、文明视野", "欲穷千里目，更上一层楼——王之涣《登鹳雀楼》"),
    ("地理意象", "玉门关", "甘肃敦煌西北", "生命禁区、春风难度", "春风不度玉门关——王之涣《凉州词》"),
    ("地理意象", "金陵", "江苏南京古称", "王朝兴衰、六朝金粉", "金陵王气黯然收——刘禹锡《西塞山怀古》"),
    ("地理意象", "剑门关", "四川剑阁险隘", "蜀道艰难、军事屏障", "剑门天下险——李白《蜀道难》"),
    ("地理意象", "蓬莱", "渤海仙山（传说）", "求仙幻梦、理想彼岸", "蓬莱文章建安骨——李白《宣州谢朓楼饯别校书叔云》"),
    ("地理意象", "洞庭", "湖南北部湖泊", "宦海沉浮、庄子秋水", "吴楚东南坼，乾坤日夜浮——杜甫《登岳阳楼》"),
]

conn = pymysql.connect(
    host='localhost',
    user='root',
    password='lzy18762501',
    database='e_rhythm',
    charset='utf8mb4'
)
cur = conn.cursor()
sql = "INSERT INTO yixiang (category, name, body, meaning, example) VALUES (%s, %s, %s, %s, %s)"
cur.executemany(sql, data)
conn.commit()
cur.close()
conn.close()
print("导入完成")
# Out:
# 导入完成

# %%
import pymysql

data = [
    ("天文意象", "参商", "参宿（猎户座）与心宿（天蝎座）", "永不相见的宿命符号（兄弟阏伯与实沈的传说）", "人生不相见，动如参与商——杜甫《赠卫八处士》"),
    ("天文意象", "北斗", "大熊座七星", "时空坐标、帝王权柄", "北斗阑干南斗斜——刘方平《月夜》"),
    ("天文意象", "银河", "天河（Milky Way）", "阻隔与相思的宇宙之河", "迢迢牵牛星，皎皎河汉女——《古诗十九首》"),
    ("天文意象", "毕宿", "金牛座α星团", "天文历法的时间锚点", "日在毕八度，谓之小满——《汉书·律历志》"),
    ("天文意象", "太白（金星）", "晨昏星", "战争预兆、孤独光辉", "太白昼见经天，秦民大恐——《史记》"),
    ("天文意象", "荧惑（火星）", "红色行星", "战争凶兆、帝王灾劫", "荧惑守心，天子失位——《史记·天官书》"),
    ("天文意象", "长庚（金星）", "黄昏出现的金星", "短暂光辉、生命终章", "长庚入梦，少微陨光——李白《与诸公送陈郎将归衡阳》"),
    ("天文意象", "天狼", "大犬座α星", "侵略象征、边患预警", "会挽雕弓如满月，西北望，射天狼——苏轼《江城子》"),
    ("天文意象", "昴宿", "金牛座星团（M45）", "团聚意象、秋收符号", "嘒彼小星，维参与昴——《诗经·召南》"),
    ("天文意象", "北辰（北极星）", "勾陈一（小熊座α）", "政治中心、道德标杆", "为政以德，譬如北辰——《论语》"),
    ("天文意象", "彗孛", "彗星", "灾异预兆、天道示警", "孛星见北斗，兵大起——《汉书·天文志》"),
    ("天文意象", "房宿", "天蝎座π-δ星群", "农事历法、四象青龙", "房星未动晨光动——王建《织锦曲》"),
    ("天文意象", "轩辕", "狮子座星群", "帝王车驾、黄帝图腾", "轩辕十四，女主昌——《开元占经》"),
    ("天文意象", "织女", "天琴座α星", "纺织劳动、爱情坚守", "迢迢牵牛星，皎皎河汉女——《古诗十九首》"),
    ("天文意象", "弧矢", "船尾座、大犬座星群", "边疆战备、武力威慑", "弧矢威天下，狼星敛锋锷——陆游《将军行》"),
]

conn = pymysql.connect(
    host='localhost',
    user='root',
    password='lzy18762501',
    database='e_rhythm',
    charset='utf8mb4'
)
cur = conn.cursor()
sql = "INSERT INTO yixiang (category, name, body, meaning, example) VALUES (%s, %s, %s, %s, %s)"
cur.executemany(sql, data)
conn.commit()
cur.close()
conn.close()
print("天文意象导入完成")
# Out:
# 天文意象导入完成

# %%
import pymysql

data = [
    ("自然意象", "梧桐", "梧桐树", "凄苦之音", "春风桃李花开日，秋雨梧桐叶落时。 ——《长恨歌》白居易"),
    ("地理意象", "长亭", "陆上的送别之所", "离别、依依不舍之情", "何处是归程？长亭更短亭。 ——《菩萨蛮》李白"),
]

conn = pymysql.connect(
    host='localhost',
    user='root',
    password='lzy18762501',
    database='e_rhythm',
    charset='utf8mb4'
)
cur = conn.cursor()
sql = "INSERT INTO yixiang (category, name, body, meaning, example) VALUES (%s, %s, %s, %s, %s)"
cur.executemany(sql, data)
conn.commit()
cur.close()
conn.close()
print("导入完成")
# Out:
# 导入完成

# %%
import pymysql

data = [
    ("器物意象", "青铜鼎", "三代礼器", "王权正统、国家重器", "问鼎中原——《左传》"),
    ("器物意象", "吴钩", "春秋弯刃兵器", "侠客精神、边塞豪情", "男儿何不带吴钩——李贺《南园》"),
    ("器物意象", "青瓷", "越窑秘色瓷", "文人雅趣、隐逸美学", "九秋风露越窑开——陆龟蒙《秘色越器》"),
    ("器物意象", "铜雀", "曹操建安台阁", "霸业成空、历史讽喻", "铜雀春深锁二乔——杜牧《赤壁》"),
    ("器物意象", "金柝", "汉代巡夜木梆", "战争记忆、时间计量", "朔气传金柝——《木兰诗》"),
    ("器物意象", "夔纹方罍", "商周青铜酒器", "神权与礼制的物质载体", "罍尊在阼，牺象在西——《礼记·明堂位》"),
    ("器物意象", "鱼符", "唐代铜制兵符", "军事信物、身份认证", "鱼书欲寄何由达——晏殊《寓意》"),
    ("器物意象", "鎏金舞马", "唐代银壶饰件", "盛世记忆、安史之殇", "屈膝衔杯赴节，倾心献寿无疆——张说《舞马词》"),
    ("器物意象", "曜变天目", "宋代建窑茶盏", "禅茶一味、宇宙幻象", "兔毫紫瓯新，蟹眼清泉煮——梅尧臣《次韵和永叔尝新茶》"),
    ("器物意象", "缂丝龙袍", "明清御用织品", "皇权物化、工艺巅峰", "织为云外秋雁行，染作江南春水色——白居易《缭绫》"),
    ("器物意象", "曾侯乙编钟", "战国青铜乐器", "礼乐文明的声学奇迹", "窈窕淑女，钟鼓乐之——《诗经·关雎》"),
    ("器物意象", "葡萄花鸟纹银香囊", "唐代陀螺仪熏香器", "闺阁情思、科技智慧", "香囊暗解，罗带轻分——秦观《满庭芳》"),
    ("器物意象", "朱漆戗金菱花盒", "宋代漆器", "市民审美、海上贸易", "螺钿妆成翡翠光——杨万里《咏漆器》"),
    ("器物意象", "青花萧何月下追韩信梅瓶", "元青花人物器", "戏剧叙事、釉下蓝彩革命", "不信楼头杨柳月，玉人歌舞未曾归——谢枋得《蚕妇吟》"),
    ("器物意象", "掐丝珐琅凫尊", "明代景泰蓝", "中西合璧、色彩霸权", "彩晕珊瑚浓，光摇琥珀薄——高启《咏珐琅器》"),
]

conn = pymysql.connect(
    host='localhost',
    user='root',
    password='lzy18762501',
    database='e_rhythm',
    charset='utf8mb4'
)
cur = conn.cursor()
sql = "INSERT INTO yixiang (category, name, body, meaning, example) VALUES (%s, %s, %s, %s, %s)"
cur.executemany(sql, data)
conn.commit()
cur.close()
conn.close()
print("器物意象导入完成")
# Out:
# 器物意象导入完成
